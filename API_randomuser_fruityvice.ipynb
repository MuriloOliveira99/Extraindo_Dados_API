# %% [markdown]
# # Python: Extraindo Dados de APIs
# - Extrair dados do `RandomUser` usando a própria lib
# - Extrair os dados da `Fruityvice API` usando `requests`
# - Extrair os dados da `Open-Joke-API` usando `requests`
# - [CognitiveClass](https://cognitiveclass.ai/)

# %% [markdown]
# ## Instalação das bibliotecas

# %%
# !pip install -q requests
# !pip install -q randomuser
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for randomuser (setup.py) ... done

# %% [markdown]
# ## Importação das bibliotecas

# %%
from randomuser import RandomUser
import requests
import pandas as pd
import json

# %% [markdown]
# ## RandomUser

# %% [markdown]
# ### Instância do RandomUser

# %%
ru = RandomUser()

# %% [markdown]
# ### Gerando 20 usuários usando a função `generate_users()`
# - Retorna uma lista de usuários

# %%
lista_usuarios = ru.generate_users(20)

# %% [markdown]
# ### Obtendo o nome completo e o email atráves dos método `get_full_name()` e `get_email()`

# %%
for usuario in lista_usuarios:
    print(
        usuario.get_full_name(),
        usuario.get_email()
    )
# Out:
# Walter Mühle walter.muhle@example.com
# Julie Jørgensen julie.jorgensen@example.com
# Brás Caldeira bras.caldeira@example.com
# Elio Riviere elio.riviere@example.com
# Sedef Abacı sedef.abaci@example.com
# آراد كامياران ard.kmyrn@example.com
# Elisa Tuft elisa.tuft@example.com
# Johnni Fletcher johnni.fletcher@example.com
# Aaron Sims aaron.sims@example.com
# Ahalam Twaalfhoven ahalam.twaalfhoven@example.com
# Thomas Vidal thomas.vidal@example.com
# Jordi Vicente jordi.vicente@example.com
# Oskari Nevala oskari.nevala@example.com
# Fernando Romero fernando.romero@example.com
# Emilie Christiansen emilie.christiansen@example.com
# Rolf-Dieter Lambrecht rolf-dieter.lambrecht@example.com
# Emilie Jensen emilie.jensen@example.com
# Filip Minge filip.minge@example.com
# Eemeli Wuollet eemeli.wuollet@example.com
# Nina Thompson nina.thompson@example.com

# %% [markdown]
# ### Obtendo a foto dos 20 usuários atráves do método `get_picture()`

# %%
for usuario in lista_usuarios:
    print(usuario.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/58.jpg
# https://randomuser.me/api/portraits/women/58.jpg
# https://randomuser.me/api/portraits/men/50.jpg
# https://randomuser.me/api/portraits/men/2.jpg
# https://randomuser.me/api/portraits/women/31.jpg
# https://randomuser.me/api/portraits/men/34.jpg
# https://randomuser.me/api/portraits/women/60.jpg
# https://randomuser.me/api/portraits/men/46.jpg
# https://randomuser.me/api/portraits/men/23.jpg
# https://randomuser.me/api/portraits/women/85.jpg
# https://randomuser.me/api/portraits/men/61.jpg
# https://randomuser.me/api/portraits/men/76.jpg
# https://randomuser.me/api/portraits/men/45.jpg
# https://randomuser.me/api/portraits/men/21.jpg
# https://randomuser.me/api/portraits/women/58.jpg
# https://randomuser.me/api/portraits/men/4.jpg
# https://randomuser.me/api/portraits/women/61.jpg
# https://randomuser.me/api/portraits/men/13.jpg
# https://randomuser.me/api/portraits/men/80.jpg
# https://randomuser.me/api/portraits/women/79.jpg

# %% [markdown]
# ### Criando uma função que retorna um DataFrame Pandas com as informações dos usuários

# %%
def get_usuarios():
    usuarios = [] # armazenar os dados do usuário

    for usuario in RandomUser.generate_users(30):
        usuarios.append({
            'Nome': usuario.get_full_name(),
            'Genero': usuario.get_gender(),
            'cidade': usuario.get_city(),
            'estado': usuario.get_state(),
            'email': usuario.get_email(),
            'dt_nasc': usuario.get_dob(),
            'foto': usuario.get_picture()
        })

    return pd.DataFrame(usuarios)

# %%
df = pd.DataFrame(get_usuarios())

# %%
df.head()
# Out:
#                Nome  Genero      cidade          estado  \
# 0   Julius Moilanen    male      Muonio    Ostrobothnia
# 1  Steven Henderson    male      Durham         Alabama
# 2      Cathy Harper  female  Gloucester  Northumberland
# 3  Leandro Monteiro    male    Araruama       São Paulo
# 4    Santana Barros    male       Serra  Santa Catarina
#
#                           email                   dt_nasc  \
# 0   julius.moilanen@example.com  1997-03-02T10:32:58.200Z
# 1  steven.henderson@example.com  1946-12-28T13:27:33.515Z
# 2      cathy.harper@example.com  1949-09-03T19:39:38.254Z
# 3  leandro.monteiro@example.com  1958-01-30T06:41:36.597Z
# 4    santana.barros@example.com  1997-05-14T11:01:05.628Z
#
#                                                foto
# 0    https://randomuser.me/api/portraits/men/26.jpg
# 1    https://randomuser.me/api/portraits/men/40.jpg
# 2  https://randomuser.me/api/portraits/women/38.jpg
# 3    https://randomuser.me/api/portraits/men/77.jpg
# 4    https://randomuser.me/api/portraits/men/85.jpg

# %% [markdown]
# ## Fruityvice API
# - Retorna informações sobre frutas
# - Obtendo os dados usando requests

# %% [markdown]
# ### Fazendo a requisição no site Fruityvice

# %%
url = 'https://fruityvice.com/api/fruit/all'
dados_frutas = requests.get(url)

# %% [markdown]
# ### Carregando os dados em um json e convertendo para texto

# %%
r = json.loads(dados_frutas.text)
print(r[0])
# Out:
# {'name': 'Persimmon', 'id': 52, 'family': 'Ebenaceae', 'order': 'Rosales', 'genus': 'Diospyros', 'nutritions': {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'carbohydrates': 18.0, 'protein': 0.0}}

# %% [markdown]
# ### Carregando os dados do json em um dataframe

# %%
pd.DataFrame(r)
# Out:
#             name  id           family             order         genus  \
# 0      Persimmon  52        Ebenaceae           Rosales     Diospyros
# 1     Strawberry   3         Rosaceae           Rosales      Fragaria
# 2         Banana   1         Musaceae      Zingiberales          Musa
# 3         Tomato   5       Solanaceae         Solanales       Solanum
# 4           Pear   4         Rosaceae           Rosales         Pyrus
# 5         Durian  60        Malvaceae          Malvales         Durio
# 6     Blackberry  64         Rosaceae           Rosales         Rubus
# 7    Lingonberry  65        Ericaceae          Ericales     Vaccinium
# 8           Kiwi  66    Actinidiaceae  Struthioniformes       Apteryx
# 9         Lychee  67      Sapindaceae        Sapindales        Litchi
# 10     Pineapple  10     Bromeliaceae            Poales        Ananas
# 11           Fig  68         Moraceae           Rosales         Ficus
# 12    Gooseberry  69  Grossulariaceae      Saxifragales         Ribes
# 13  Passionfruit  70   Passifloraceae      Malpighiales    Passiflora
# 14          Plum  71         Rosaceae           Rosales        Prunus
# 15        Orange   2         Rutaceae        Sapindales        Citrus
# 16    GreenApple  72         Rosaceae           Rosales         Malus
# 17     Raspberry  23         Rosaceae           Rosales         Rubus
# 18    Watermelon  25    Cucurbitaceae      Cucurbitales     Citrullus
# 19         Lemon  26         Rutaceae        Sapindales        Citrus
# 20         Mango  27    Anacardiaceae        Sapindales     Mangifera
# 21     Blueberry  33         Rosaceae           Rosales      Fragaria
# 22         Apple   6         Rosaceae           Rosales         Malus
# 23         Guava  37        Myrtaceae          Myrtales       Psidium
# 24       Apricot  35         Rosaceae           Rosales        Prunus
# 25        Papaya  42       Caricaceae         Caricacea        Carica
# 26         Melon  41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 27     Tangerine  77         Rutaceae        Sapindales        Citrus
# 28      Pitahaya  78        Cactaceae    Caryophyllales     Cactaceae
# 29          Lime  44         Rutaceae        Sapindales        Citrus
# 30   Pomegranate  79       Lythraceae          Myrtales        Punica
# 31   Dragonfruit  80        Cactaceae    Caryophyllales  Selenicereus
# 32         Grape  81         Vitaceae           Vitales         Vitis
# 33         Morus  82         Moraceae           Rosales         Morus
# 34        Feijoa  76        Myrtaceae        Myrtoideae    Sellowiana
# 35       Avocado  84        Lauraceae          Laurales        Persea
# 36     Kiwifruit  85    Actinidiaceae          Ericales     Actinidia
# 37     Cranberry  87        Ericaceae          Ericales     Vaccinium
# 38        Cherry   9         Rosaceae           Rosales        Prunus
# 39         Peach  86         Rosaceae           Rosales        Prunus
# 40     Jackfruit  94         Moraceae           Rosales    Artocarpus
# 41  Horned Melon  95    Cucurbitaceae      Cucurbitales       Cucumis
# 42      Hazelnut  96       Betulaceae           Fagales       Corylus
# 43        Pomelo  98         Rutaceae        Sapindales        Citrus
# 44    Mangosteen  99       Clusiaceae      Malpighiales      Garcinia
#
#                                            nutritions
# 0   {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'c...
# 1   {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 2   {'calories': 96, 'fat': 0.2, 'sugar': 17.2, 'c...
# 3   {'calories': 74, 'fat': 0.2, 'sugar': 2.6, 'ca...
# 4   {'calories': 57, 'fat': 0.1, 'sugar': 10.0, 'c...
# 5   {'calories': 147, 'fat': 5.3, 'sugar': 6.75, '...
# 6   {'calories': 40, 'fat': 0.4, 'sugar': 4.5, 'ca...
# 7   {'calories': 50, 'fat': 0.34, 'sugar': 5.74, '...
# 8   {'calories': 61, 'fat': 0.5, 'sugar': 9.0, 'ca...
# 9   {'calories': 66, 'fat': 0.44, 'sugar': 15.0, '...
# 10  {'calories': 50, 'fat': 0.12, 'sugar': 9.85, '...
# 11  {'calories': 74, 'fat': 0.3, 'sugar': 16.0, 'c...
# 12  {'calories': 44, 'fat': 0.6, 'sugar': 0.0, 'ca...
# 13  {'calories': 97, 'fat': 0.7, 'sugar': 11.2, 'c...
# 14  {'calories': 46, 'fat': 0.28, 'sugar': 9.92, '...
# 15  {'calories': 43, 'fat': 0.2, 'sugar': 8.2, 'ca...
# 16  {'calories': 21, 'fat': 0.1, 'sugar': 6.4, 'ca...
# 17  {'calories': 53, 'fat': 0.7, 'sugar': 4.4, 'ca...
# 18  {'calories': 30, 'fat': 0.2, 'sugar': 6.0, 'ca...
# 19  {'calories': 29, 'fat': 0.3, 'sugar': 2.5, 'ca...
# 20  {'calories': 60, 'fat': 0.38, 'sugar': 13.7, '...
# 21  {'calories': 29, 'fat': 0.4, 'sugar': 5.4, 'ca...
# 22  {'calories': 52, 'fat': 0.4, 'sugar': 10.3, 'c...
# 23  {'calories': 68, 'fat': 1.0, 'sugar': 9.0, 'ca...
# 24  {'calories': 15, 'fat': 0.1, 'sugar': 3.2, 'ca...
# 25  {'calories': 43, 'fat': 0.4, 'sugar': 1.0, 'ca...
# 26  {'calories': 34, 'fat': 0.0, 'sugar': 8.0, 'ca...
# 27  {'calories': 45, 'fat': 0.4, 'sugar': 9.1, 'ca...
# 28  {'calories': 36, 'fat': 0.4, 'sugar': 3.0, 'ca...
# 29  {'calories': 25, 'fat': 0.1, 'sugar': 1.7, 'ca...
# 30  {'calories': 83, 'fat': 1.2, 'sugar': 13.7, 'c...
# 31  {'calories': 60, 'fat': 1.5, 'sugar': 8.0, 'ca...
# 32  {'calories': 69, 'fat': 0.16, 'sugar': 16.0, '...
# 33  {'calories': 43, 'fat': 0.39, 'sugar': 8.1, 'c...
# 34  {'calories': 44, 'fat': 0.4, 'sugar': 3.0, 'ca...
# 35  {'calories': 160, 'fat': 14.66, 'sugar': 0.66,...
# 36  {'calories': 61, 'fat': 0.5, 'sugar': 8.9, 'ca...
# 37  {'calories': 46, 'fat': 0.1, 'sugar': 4.0, 'ca...
# 38  {'calories': 50, 'fat': 0.3, 'sugar': 8.0, 'ca...
# 39  {'calories': 39, 'fat': 0.25, 'sugar': 8.4, 'c...
# 40  {'calories': 95, 'fat': 0.0, 'sugar': 19.1, 'c...
# 41  {'calories': 44, 'fat': 1.26, 'sugar': 0.5, 'c...
# 42  {'calories': 628, 'fat': 61.0, 'sugar': 4.3, '...
# 43  {'calories': 37, 'fat': 0.0, 'sugar': 8.5, 'ca...
# 44  {'calories': 73, 'fat': 0.58, 'sugar': 16.11, ...

# %% [markdown]
# ### O resultado está em um formato json aninhado. A coluna 'nutrição' contém múltiplas subcolunas, portanto os dados precisam ser normalizados.
# - A coluna nutrição está assim: {'calories': 81, 'fat': 0.0, 'sugar': 18.0, 'carbohydrates': 18.0, 'protein': 0.0}
# - json_normalize irá separá-las em colunas
#     - calories
#     - fat
#     - sugar
#     - carbohydrates
#     - protein

# %%
df2 = pd.json_normalize(r)

# %%
df2.head(1)
# Out:
#         name  id     family    order      genus  nutritions.calories  \
# 0  Persimmon  52  Ebenaceae  Rosales  Diospyros                   81
#
#    nutritions.fat  nutritions.sugar  nutritions.carbohydrates  \
# 0             0.0              18.0                      18.0
#
#    nutritions.protein
# 0                 0.0

# %% [markdown]
# ### Renomeando as colunas

# %%
df2.rename(columns={
    'nutritions.calories': 'calories',
    'nutritions.fat': 'fat',
    'nutritions.sugar': 'sugar',
    'nutritions.carbohydrates': 'carbohydrates',
    'nutritions.protein': 'protein'
}, inplace=True)

# %%
df2.head(1)
# Out:
#         name  id     family    order      genus  calories  fat  sugar  \
# 0  Persimmon  52  Ebenaceae  Rosales  Diospyros        81  0.0   18.0
#
#    carbohydrates  protein
# 0           18.0      0.0

# %% [markdown]
# ### Gerando um novo DataFrame com os dados de 'Cherry'

# %%
df_cherry = df2.loc[df2['name'] == 'Cherry']
df_cherry.head()
# Out:
#       name  id    family    order   genus  calories  fat  sugar  \
# 38  Cherry   9  Rosaceae  Rosales  Prunus        50  0.3    8.0
#
#     carbohydrates  protein
# 38           12.0      1.0

# %%
(df_cherry.iloc[0]['family']) , (df_cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ### Gerando um novo DataFrame com os dados de 'Banana'

# %%
df_banana = df2.loc[df2['name'] == 'Banana']
df_banana.head()
# Out:
#      name  id    family         order genus  calories  fat  sugar  \
# 2  Banana   1  Musaceae  Zingiberales  Musa        96  0.2   17.2
#
#    carbohydrates  protein
# 2           22.0      1.0

# %%
df_banana.iloc[0]['calories']
# Out:
# 96

# %% [markdown]
# ## Official Joke API
# - É uma API de piadas
# - Obtendo os dados usando requests

# %% [markdown]
# ### Fazendo a requisição no site 'Official Joke API'

# %%
url = 'https://official-joke-api.appspot.com/jokes/ten'
dados_joke = requests.get(url)

# %% [markdown]
# ### Carregando os Dados em um json e convertendo texto

# %%
r2 = json.loads(dados_joke.text)
print(r2[0])
# Out:
# {'type': 'general', 'setup': 'What did the 0 say to the 8?', 'punchline': 'Nice belt.', 'id': 167}

# %% [markdown]
# ### Convertendo o json para DataFrame Pandas

# %%
df3 = pd.DataFrame(r2)
df3.head()
# Out:
#       type                                              setup  \
# 0  general                       What did the 0 say to the 8?
# 1  general       How come the stadium got hot after the game?
# 2  general           What time did the man go to the dentist?
# 3  general  Why did the girl smear peanut butter on the road?
# 4  general                     Two guys walk into a bar . . .
#
#                                            punchline   id
# 0                                         Nice belt.  167
# 1                      Because all of the fans left.  116
# 2                                      Tooth hurt-y.  265
# 3                        To go with the traffic jam.  330
# 4  The first guy says "Ouch!" and the second says...  372

# %%
df3['type'].value_counts()
# Out:
# general    10
# Name: type, dtype: int64

# %% [markdown]
# ### Deletando as colunas 'type' e 'id'

# %%
df3.drop(columns=['type', 'id'], inplace=True)
df3.head(1)
# Out:
#                           setup   punchline
# 0  What did the 0 say to the 8?  Nice belt.
